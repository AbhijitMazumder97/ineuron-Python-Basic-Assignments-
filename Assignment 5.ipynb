# %% [markdown]
# Q1. What does an empty dictionary's code look like?
#
# Answer:
# {}

# %% [markdown]
# Q2. What is the value of a dictionary value with the key 'foo' and the value 42?
#
# Answer:
#
# {'foo':42}

# %%
dic_nry={'foo':42}

# %%
dic_nry
# Out:
# {'foo': 42}

# %% [markdown]
# Q3. What is the most significant distinction between a dictionary and a list?
#
# Answer:
# Unlike lists, items in dictionaries are unordered. The order of items matters for determining whether two lists are the same, it does not matter in what order the key-value pairs are typed in a dictionary.Because dictionaries are not ordered, they can’t be sliced like lists.

# %% [markdown]
# Q4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
#
# Answer:
# I'll get a Key Error.

# %%
spam={'bar':100}

# %%
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7876/3999281786.py in <module>
# ----> 1 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# Q5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
#
# Answer:
#
# No difference.

# %%
spam={'species': 'cat', 'age': '8', 'name': 'Zophie'}

# %%
'cat' in spam
# Out:
# False

# %%
'cat' in spam.keys()
# Out:
# False

# %%
spam={'cat':'Scottish Fold','dog':'Indian Spitz'}

# %%
'cat' in spam
# Out:
# True

# %%
'cat' in spam.keys()
# Out:
# True

# %% [markdown]
# Q6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
#
# Answer:  There is a difference,

# %%
spam
# Out:
# {'cat': 'Scottish Fold', 'dog': 'Indian Spitz'}

# %%
'cat' in spam
# Out:
# True

# %%
'cat' in spam.values()
# Out:
# False

# %%
'Scottish Fold' in spam
# Out:
# False

# %%
'Scottish Fold' in spam.values()
# Out:
# True

# %% [markdown]
# Q7. What is a shortcut for the following code?
#
#
# if 'color' not in spam:
#
#         spam['color'] = 'black'

# %%
if 'color' not in spam:
    spam['color'] = 'black'

# %%
spam
# Out:
# {'cat': 'Scottish Fold', 'dog': 'Indian Spitz', 'color': 'black'}

# %%
del spam['color']

# %%
spam
# Out:
# {'cat': 'Scottish Fold', 'dog': 'Indian Spitz'}

# %%
spam.setdefault('color','black')
# Out:
# 'black'

# %%
spam
# Out:
# {'cat': 'Scottish Fold', 'dog': 'Indian Spitz', 'color': 'black'}

# %% [markdown]
# Q8. How do you "pretty print" dictionary values using which module and function?
#
# Answer:
#
# We use the pprint module and the pprint() function to "pretty print" dictionary values.
#
# pprint.pprint()
